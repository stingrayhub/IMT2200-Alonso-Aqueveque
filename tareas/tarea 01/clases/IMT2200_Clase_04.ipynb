# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>
# ---

# %% [markdown]
# # <h1><center>Clase 04: Trabajo con Datos Semi Estructurados</center></h1>
#
# Este ejercicio busca que los estudiantes aprendan a usar librerias en Python para la gestión y exploración de datos semi estructurados.

# %% [markdown]
# ## 1. Datos para los ejemplos
#
# Usaremos dos conjuntos de datos para este Notebook:
# <ol>
# <li>Datos de Yelp sobre restaurantes de Santiago:</li>
#
# Estos datos fueron proporcionados por la profesora Paula Aguirre y están en el archivo `restaurants.json` en la carpeta de `data`.
#
#
# <li>Datos de conciertos de la Filarmónica de NY:</li>
#
# La orquesta filarmónica de Nueva York, ha puesto a disposición del público los datos de las más de 20,000 presentaciones que han hecho desde el 7 de diciembre de 1842, contando con una base de más de 180 años de presentaciones.
#
# La base de datos original puede ser accedida en forma interactiva en https://archives.nyphil.org/performancehistory/#program.op y la base completa está disponible en el sitio de GitHub de la Filarmónica: https://github.com/nyphilarchive/PerformanceHistory
# </ol>

# %% [markdown]
# ## 2. Manipulación de datos en formato json
#
# Uno de los formatos preferidos para datos semi estructurados es el formato json. Python cuenta con una libraría especial para trabajar con este tipo de formato: https://docs.python.org/3/library/json.html y nos permite leer y escribir en este formato entre otras cosas.
#
# A continuación cargaremos las librerías necesarias para este ejercicio.

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import json

# %%
# %cd data
# Out:
# C:\Users\rodri\OneDrive\Personal\UC\courses\IMC pregrado\imt2200 introducción a ciencia de datos\lectures\clase 04\data

# %% [markdown]
# ## 3. Introducción a json
#
# ### 3.1 Creando un set de datos simple
#
# Armemos una lista de curso de alumnos en la universidad por generación, incporporando datos adicionales, como profesores y notas cuando estén estas disponibles. Comenzaremos con un `list` en Python para almacenar cada generación.

# %%
json_list = [
    { 
        'class': 'Year 1', 
        'student count': 35, 
        'room': 'A2',
        'info': {
            'teachers': { 
                'math': 'Emmy Noether', 
                'physics': 'Richard Feynman' 
            }
        },
        'students': [
            { 
                'name': 'Mary', 
                'sex': 'F', 
                'grades': { 'math': 75, 'physics': 98 } 
            },
            { 
                'name': 'James', 
                'sex': 'M', 
                'grades': { 'math': 80, 'physics': 78 } 
            },
        ]
    },
    { 
        'class': 'Year 2', 
        'student count': 28, 
        'room': 'A4',
        'info': {
            'teachers': { 
                'math': 'Alan Turing', 
                'physics': 'Vera Rubin' 
            }
        },
        'students': [
            { 'name': 'Tony', 'sex': 'M' },
            { 'name': 'Jacqueline', 'sex': 'F' },
        ]
    },
]

# %%
json_list[0]
# Out:
# {'class': 'Year 1',
#  'student count': 35,
#  'room': 'A2',
#  'info': {'teachers': {'math': 'Emmy Noether', 'physics': 'Richard Feynman'}},
#  'students': [{'name': 'Mary',
#    'sex': 'F',
#    'grades': {'math': 75, 'physics': 98}},
#   {'name': 'James', 'sex': 'M', 'grades': {'math': 80, 'physics': 78}}]}

# %%
json_list[0].keys()
# Out:
# dict_keys(['class', 'student count', 'room', 'info', 'students'])

# %%
json_list[0]['class']
# Out:
# 'Year 1'

# %%
json_list[0]['students']
# Out:
# [{'name': 'Mary', 'sex': 'F', 'grades': {'math': 75, 'physics': 98}},
#  {'name': 'James', 'sex': 'M', 'grades': {'math': 80, 'physics': 78}}]

# %% [markdown]
# Usando Pandas podemos intentar transformar un archivo json en un DataFrame estructurado:

# %%
df = pd.DataFrame(json_list)
df.head()
# Out:
#     class  student count room  \
# 0  Year 1             35   A2
# 1  Year 2             28   A4
#
#                                                 info  \
# 0  {'teachers': {'math': 'Emmy Noether', 'physics...
# 1  {'teachers': {'math': 'Alan Turing', 'physics'...
#
#                                             students
# 0  [{'name': 'Mary', 'sex': 'F', 'grades': {'math...
# 1  [{'name': 'Tony', 'sex': 'M'}, {'name': 'Jacqu...

# %%
df['students']
# Out:
# 0    [{'name': 'Mary', 'sex': 'F', 'grades': {'math...
# 1    [{'name': 'Tony', 'sex': 'M'}, {'name': 'Jacqu...
# Name: students, dtype: object

# %%
df['students'][0]
# Out:
# [{'name': 'Mary', 'sex': 'F', 'grades': {'math': 75, 'physics': 98}},
#  {'name': 'James', 'sex': 'M', 'grades': {'math': 80, 'physics': 78}}]

# %%
df['students'][0][0]
# Out:
# {'name': 'Mary', 'sex': 'F', 'grades': {'math': 75, 'physics': 98}}

# %% [markdown]
# ### 3.2 Transformando un json en un DataFrame
#
# El comando anterior no nos generó un DataFrame muy útil, pues muchos de los elementos son diccionarios adentro de una posición.
#
# Una característica común del formato `json`, y es porque los usamos, es que pueden ser anidado: el valor de un atributo pueder ser un nuevo diccionario, o una lista de diccionarios. Este tipo de datos anidados es más conveniente de utilizar en formato "aplanado" o "flattened", de manera que pueda ser almacenado en un DataFrame. La librería `pandas` tiene la función `json_normalize()` que hace exactamente esto por nosotros. Pueden encontrar más detalles en: https://pandas.pydata.org/pandas-docs/version/1.2.0/reference/api/pandas.json_normalize.html

# %%
all_students = pd.json_normalize(json_list, sep=".")
type(all_students)
# Out:
# pandas.core.frame.DataFrame

# %%
all_students.head()
# Out:
#     class  student count room  \
# 0  Year 1             35   A2
# 1  Year 2             28   A4
#
#                                             students info.teachers.math  \
# 0  [{'name': 'Mary', 'sex': 'F', 'grades': {'math...       Emmy Noether
# 1  [{'name': 'Tony', 'sex': 'M'}, {'name': 'Jacqu...        Alan Turing
#
#   info.teachers.physics
# 0       Richard Feynman
# 1            Vera Rubin

# %% [markdown]
# La función `json_normalize` expande automáticamente todos los diccionarios anidados. Si tenemos también listas de diccionarios (como ocurre con `students`), hay que usar el parámetro `path_record` para expandir los diccionarios contenidos dentro de la lista.

# %%
all_students = pd.json_normalize(json_list, sep="_", record_path=['students'])
all_students.head()
# Out:
#          name sex  grades_math  grades_physics
# 0        Mary   F         75.0            98.0
# 1       James   M         80.0            78.0
# 2        Tony   M          NaN             NaN
# 3  Jacqueline   F          NaN             NaN

# %% [markdown]
# Esto nos permitió ordenar por alumno, pero nos quedó afuera mucha información asociada al alumno. Para agregarla debemos indicar, usando el parámetro `meta` la información adicional a copiar.

# %%
all_students_grades = pd.json_normalize(json_list, sep="_", record_path=['students'], meta=['class','student count','room','info'], max_level=None)
all_students_grades.head()
# Out:
#          name sex  grades_math  grades_physics   class student count room  \
# 0        Mary   F         75.0            98.0  Year 1            35   A2
# 1       James   M         80.0            78.0  Year 1            35   A2
# 2        Tony   M          NaN             NaN  Year 2            28   A4
# 3  Jacqueline   F          NaN             NaN  Year 2            28   A4
#
#                                                 info
# 0  {'teachers': {'math': 'Emmy Noether', 'physics...
# 1  {'teachers': {'math': 'Emmy Noether', 'physics...
# 2  {'teachers': {'math': 'Alan Turing', 'physics'...
# 3  {'teachers': {'math': 'Alan Turing', 'physics'...

# %% [markdown]
# Podemos expandir aún más la información, agregando los detalles por profesor.

# %%
all_students_grades= pd.json_normalize(json_list, sep="_", record_path=['students'], meta=['class','student count','room',['info','teachers','math'], ['info','teachers','physics']], max_level=None)
all_students_grades.head()
# Out:
#          name sex  grades_math  grades_physics   class student count room  \
# 0        Mary   F         75.0            98.0  Year 1            35   A2
# 1       James   M         80.0            78.0  Year 1            35   A2
# 2        Tony   M          NaN             NaN  Year 2            28   A4
# 3  Jacqueline   F          NaN             NaN  Year 2            28   A4
#
#   info_teachers_math info_teachers_physics
# 0       Emmy Noether       Richard Feynman
# 1       Emmy Noether       Richard Feynman
# 2        Alan Turing            Vera Rubin
# 3        Alan Turing            Vera Rubin

# %%
# almacenar la información bajo este orden en un archivo json
all_students_grades.to_json('students.json')

# %% [markdown]
# ## 4. Lectura de un archivo json
#
# La librería `json` también nos permite leer este tipo de formato e importar directamente a nuestro código. Hagamos el ejemplo con los datos de restaurantes de santiago de Yelp.

# %%
restaurantes = json.load(open('restaurants.json','r'))
type(restaurantes)
# Out:
# dict

# %%
restaurantes
# Out:
# {'businesses': [{'id': '8N6Y3HsLXHBeFwhlO0YxwQ',
#    'alias': 'barrica-94-santiago',
#    'name': 'Barrica 94',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nuJaODltnNB6J_ww3g-JyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrica-94-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 72,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'chilean', 'title': 'Chilean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4342880070125,
#     'longitude': -70.6352240592241},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Bellavista 052',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Bellavista 052', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+5627324939',
#    'display_phone': '+56 27324939',
#    'distance': 1390.184857350938},
#   {'id': 'KQ2D3gs9y0wIuTqoKOHO4w',
#    'alias': 'mestizo-santiago',
#    'name': 'Mestizo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XBkpGrI0Rz7ZVn0Nu3TGhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mestizo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 52,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'},
#     {'alias': 'international', 'title': 'International'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.394083457956,
#     'longitude': -70.600033248157},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Av. del Bicentenario 4050',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. del Bicentenario 4050',
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+56974776093',
#    'display_phone': '+56 9 7477 6093',
#    'distance': 6024.195624577105},
#   {'id': 'y2FR-JBGie4wiW6RjtKLhg',
#    'alias': 'aquí-está-coco-santiago',
#    'name': 'Aquí Está Coco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6IkPzbpIYkumSEMoFkiuFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqu%C3%AD-est%C3%A1-coco-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 52,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.42406349, 'longitude': -70.61662393},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'La Concepción 236',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['La Concepción 236', 'RM Santiago', 'Chile']},
#    'phone': '+5624106200',
#    'display_phone': '+56 24106200',
#    'distance': 2355.685975177847},
#   {'id': 'FTnehJpfn5t3iq_eGcE6pg',
#    'alias': 'galindo-santiago',
#    'name': 'Galindo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GHOdcjiCfiH30f6T29sUoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galindo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 57,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.433069, 'longitude': -70.634928},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Dardignac 98',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Dardignac 98', 'RM 7500000 Santiago', 'Chile']},
#    'phone': '+56227770116',
#    'display_phone': '+56 2 2777 0116',
#    'distance': 1480.4705689071582},
#   {'id': 'CAFL80wAGOMcPrEO6uMnkA',
#    'alias': 'fuente-alemana-santiago-2',
#    'name': 'Fuente Alemana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BqZVmtoAeW8VfMvCQ8BOog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuente-alemana-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 55,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4375198417072,
#     'longitude': -70.6360235448149},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': "Av. Libertador Bernardo O'Higgins 58",
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ["Av. Libertador Bernardo O'Higgins 58",
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+5626393231',
#    'display_phone': '+56 26393231',
#    'distance': 1197.179790269262},
#   {'id': '2K3dN-x3HovH1d_MPh9NIw',
#    'alias': 'in-pasta-santiago',
#    'name': 'In Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1Z1phb9F8d-6zmA2WFntKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/in-pasta-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.4466879406616,
#     'longitude': -70.626129307522},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Sta. Isabel 0395',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8150000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Sta. Isabel 0395', 'RM 8150000 Santiago', 'Chile']},
#    'phone': '+56226347575',
#    'display_phone': '+56 2 2634 7575',
#    'distance': 316.2550555844538},
#   {'id': 'ioWH5y3-c9AmZAsVabDwAA',
#    'alias': 'la-burguesía-santiago',
#    'name': 'La Burguesía',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KWRy8w8X5nrufsgQa5NW3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-burgues%C3%ADa-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 31,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.420414, 'longitude': -70.609573},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Santa Magdalena 99',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7510038',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Santa Magdalena 99', 'RM 7510038 Santiago', 'Chile']},
#    'phone': '+56222313407',
#    'display_phone': '+56 2 2231 3407',
#    'distance': 3003.568410528073},
#   {'id': 'Qtni8AS93H71AfyDIsijZg',
#    'alias': 'casaluz-santiago-4',
#    'name': 'Casaluz',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ilrP85BexenOWGwL_BvS2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casaluz-santiago-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 26,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.442185, 'longitude': -70.626424},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Italia 805',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7501184',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Italia 805', 'RM 7501184 Santiago', 'Chile']},
#    'phone': '+56229187204',
#    'display_phone': '+56 2 2918 7204',
#    'distance': 202.71734071977343},
#   {'id': 'FcQ0WD5LiJTxCZ0kGH2yww',
#    'alias': 'silvestre-bistró-santiago',
#    'name': 'Silvestre Bistró',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f1Fc26Wou2DE5IGHzkYJRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silvestre-bistr%C3%B3-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 15,
#    'categories': [{'alias': 'signature_cuisine',
#      'title': 'Signature Cuisine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.448243, 'longitude': -70.6236202},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Caupolicán 511',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Caupolicán 511', 'RM Santiago', 'Chile']},
#    'phone': '+56991569974',
#    'display_phone': '+56 9 9156 9974',
#    'distance': 519.4119376281693},
#   {'id': 'LGwEqYL0reUsRdtqE44ITQ',
#    'alias': 'chipe-libre-república-independiente-del-pisco-santiago-2',
#    'name': 'Chipe Libre - República Independiente del Pisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZXTniS5ztC85xXcerJDDZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chipe-libre-rep%C3%BAblica-independiente-del-pisco-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 62,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4383392, 'longitude': -70.6411438},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'José Victorino Lastarria 282',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320156',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['José Victorino Lastarria 282',
#      'RM 8320156 Santiago',
#      'Chile']},
#    'phone': '+56226640584',
#    'display_phone': '+56 2 2664 0584',
#    'distance': 1567.3269069210853},
#   {'id': '9L7D68rsmWKp3ynU8xA4TQ',
#    'alias': 'la-mar-santiago',
#    'name': 'La Mar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XU67DRi_Ep-6vPATIYaQeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-mar-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 33,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.3997243, 'longitude': -70.5909546},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Av. Nueva Costanera 4076',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7630000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Nueva Costanera 4076',
#      'RM 7630000 Santiago',
#      'Chile']},
#    'phone': '+56222067839',
#    'display_phone': '+56 2 2206 7839',
#    'distance': 5869.266489670384},
#   {'id': 'IUBOvOYsrcyRMdp8V2O06g',
#    'alias': 'la-diana-santiago',
#    'name': 'La Diana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HOSB4Lu1uRHPELjpTYzMWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-diana-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 13,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.450898, 'longitude': -70.649611},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Arturo Prat 435',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Arturo Prat 435', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+56226649018',
#    'display_phone': '+56 2 2664 9018',
#    'distance': 2359.673541949187},
#   {'id': 'EG1MtnU1CapiqemCj9gPDg',
#    'alias': 'la-hacienda-gaucha-santiago-2',
#    'name': 'La Hacienda Gaucha',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YiUIO9cx1MLEXR5WakCR_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-hacienda-gaucha-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 12,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4386931069913,
#     'longitude': -70.6081252589997},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Pedro de Valdivia 1719',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7810000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Pedro de Valdivia 1719',
#      'RM 7810000 Santiago',
#      'Chile']},
#    'phone': '+5622235305',
#    'display_phone': '+56 22235305',
#    'distance': 1721.7375728313675},
#   {'id': 'ymAS7H4ffmiJ8blD-8-ZJA',
#    'alias': 'donde-guido-santiago-2',
#    'name': 'Donde Guido',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxKDsPQp6Beb1bcgwOdrmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donde-guido-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 10,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4387989, 'longitude': -70.648148},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'San Antonio 349',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['San Antonio 349', 'RM Santiago', 'Chile']},
#    'phone': '+56989107224',
#    'display_phone': '+56 9 8910 7224',
#    'distance': 2166.0819630617566},
#   {'id': 'oZ_pVyyyGS8mghqZ9X_NUw',
#    'alias': 'baco-santiago',
#    'name': 'Baco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OoXeaAW_z40eR0mADp7Q3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baco-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 60,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.42095352, 'longitude': -70.61044579},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Nueva de Lyon 113',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Nueva de Lyon 113', 'RM Santiago', 'Chile']},
#    'phone': '+56222314444',
#    'display_phone': '+56 2 2231 4444',
#    'distance': 2911.6098888806855},
#   {'id': 'h8xupzTNMpFy8baMOJtAGg',
#    'alias': 'jardin-mallinkrodt-providencia',
#    'name': 'Jardin Mallinkrodt',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XQRW8033SCItFOJO0236LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jardin-mallinkrodt-providencia?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 4,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.43241, 'longitude': -70.63373},
#    'transactions': [],
#    'location': {'address1': 'Mallinkrodt 170',
#     'address2': '',
#     'address3': None,
#     'city': 'Providencia',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Mallinkrodt 170', 'RM Providencia', 'Chile']},
#    'phone': '+56959066635',
#    'display_phone': '+56 9 5906 6635',
#    'distance': 1485.1040922091163},
#   {'id': 'iGvD2zDHJA6n21676oRyNg',
#    'alias': 'fiddlers-santiago-3',
#    'name': 'Fiddlers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ikb8Tpz6QjgnawAcB_UrXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiddlers-santiago-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 14,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4293153, 'longitude': -70.618948},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Dr. Manuel Barros Borgoño 13',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Dr. Manuel Barros Borgoño 13',
#      'RM 7500000 Santiago',
#      'Chile']},
#    'phone': '+56975607001',
#    'display_phone': '+56 9 7560 7001',
#    'distance': 1733.1836326600185},
#   {'id': 'H6viU-g0AtQ5HDGGG9Rq-w',
#    'alias': 'la-iberica-santiago-2',
#    'name': 'La Iberica',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1hojrv398PscV2IfhJ2DrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-iberica-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 9,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4461459, 'longitude': -70.6249411},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Santa Isabel 462',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Santa Isabel 462', 'RM Santiago', 'Chile']},
#    'phone': '+56954068065',
#    'display_phone': '+56 9 5406 8065',
#    'distance': 259.8250735574533},
#   {'id': 'uBP5ISVSd5D0eEJTgLtmnQ',
#    'alias': 'marisquería-clarita-santiago',
#    'name': 'Marisquería Clarita',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HRj2LHyDsxKoqlWKxPEkAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marisquer%C3%ADa-clarita-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 5,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4343338, 'longitude': -70.651474},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'San Pablo 1000',
#     'address2': 'Loc. 97',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['San Pablo 1000', 'Loc. 97', 'RM Santiago', 'Chile']},
#    'phone': '+5626873975',
#    'display_phone': '+56 26873975',
#    'distance': 2645.6916102352584},
#   {'id': 'dVg6qgx4tZZbdNiAuud1wQ',
#    'alias': 'restaurant-ocean-pacific-santiago',
#    'name': 'Restaurant Ocean Pacific',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c7cU-HmKmd_zuSj-nAVqSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-ocean-pacific-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 12,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.44214924, 'longitude': -70.66791546},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Avenida Ricardo Cumming 221',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Avenida Ricardo Cumming 221',
#      'RM Santiago',
#      'Chile']},
#    'phone': '+56227700300',
#    'display_phone': '+56 2 2770 0300',
#    'distance': 3929.967936193933},
#   {'id': 'iSw2Zlx8kz9ECDhTkqVt1A',
#    'alias': 'los-cuates-santiago',
#    'name': 'Los Cuates',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sc5C0FGX0HPSJwcfwgMndQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-cuates-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 18,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4307244251916,
#     'longitude': -70.6190610363212},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Avenida Manuel Montt 235',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Avenida Manuel Montt 235', 'RM Santiago', 'Chile']},
#    'phone': '+5622642376',
#    'display_phone': '+56 22642376',
#    'distance': 1583.730375722951},
#   {'id': 'LyUwbW2c_0TpaYLp1tY0Gg',
#    'alias': 'el-camino-santiago',
#    'name': 'El Camino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZqtwXiubcFQUvhFO3jqLtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-camino-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 12,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': -33.44413, 'longitude': -70.62555},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Italia 1034',
#     'address2': None,
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7501297',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Italia 1034', 'RM 7501297 Santiago', 'Chile']},
#    'phone': '+56229860765',
#    'display_phone': '+56 2 2986 0765',
#    'distance': 25.192076784947314},
#   {'id': 'COqOSJ1EIeGC91PcpgKpWQ',
#    'alias': 'la-serrana-santiago',
#    'name': 'La Serrana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O4IEU889ANShrmqI_4RXBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-serrana-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 9,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4467390683777,
#     'longitude': -70.6489891558886},
#    'transactions': [],
#    'location': {'address1': 'Serrano 163',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Serrano 163', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+56226322879',
#    'display_phone': '+56 2 2632 2879',
#    'distance': 2192.3620343452058},
#   {'id': 'pIaTdO4k6MDcin_I4SF6ig',
#    'alias': 'biwon-santiago',
#    'name': 'Biwon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QAuleM-raji3gU_8xY5igQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biwon-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 4,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.4223375, 'longitude': -70.6053371},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Coronel 2376',
#     'address2': 'Providencia',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Coronel 2376',
#      'Providencia',
#      'RM Santiago',
#      'Chile']},
#    'phone': '+56229518000',
#    'display_phone': '+56 2 2951 8000',
#    'distance': 3045.576110341096},
#   {'id': 'JPqsTHbGkMvi268nKl7lZQ',
#    'alias': 'la-chimenea-santiago',
#    'name': 'La Chimenea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hoa_UgOnQmyGgy1EM1e1uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-chimenea-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 7,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4427950612347, 'longitude': -70.65673703},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Príncipe de Gales 90',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Príncipe de Gales 90',
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+56226970131',
#    'display_phone': '+56 2 2697 0131',
#    'distance': 2890.5752082088707},
#   {'id': 'ffHk4q3jDiMrTMLLU6kcIA',
#    'alias': 'tiramisú-santiago-2',
#    'name': 'Tiramisú',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DL9gg32FNJIqTkpVZ6owiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiramis%C3%BA-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 83,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.414562406985,
#     'longitude': -70.597506713488},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Av. Isidora Goyenechea 3141',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7550000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Isidora Goyenechea 3141',
#      'RM 7550000 Santiago',
#      'Chile']},
#    'phone': '+56225194900',
#    'display_phone': '+56 2 2519 4900',
#    'distance': 4174.546059246231},
#   {'id': '0mL2MwydItat3Bnb8U7cXQ',
#    'alias': 'italissimo-santiago',
#    'name': 'Italissimo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y17VNMDAaQYI374ha52bYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italissimo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4423375204196, 'longitude': -70.657609},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Moneda 1495',
#     'address2': '',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8340484',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Moneda 1495', 'RM 8340484 Santiago', 'Chile']},
#    'phone': '+56226721878',
#    'display_phone': '+56 2 2672 1878',
#    'distance': 2973.9143258401004},
#   {'id': 'bljvdr1cBOVSHrbTp4E-Iw',
#    'alias': 'tostao-y-madera-santiago',
#    'name': 'Tostao & Madera',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U7-RcGnb9nOMKxQH37JlUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tostao-y-madera-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 2,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4351944333928, 'longitude': -70.627883},
#    'transactions': [],
#    'location': {'address1': 'Boulevard Avenida Providencia 455',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Boulevard Avenida Providencia 455',
#      'RM 7500000 Santiago',
#      'Chile']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 988.2117647429537},
#   {'id': 'ru9I6hxoA3HqkkZpZ0p5UQ',
#    'alias': 'new-horizon-santiago-2',
#    'name': 'New Horizon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/89oPBvcoSdqdpN_A8JMI-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-horizon-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 28,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.437766, 'longitude': -70.64511},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Merced 565',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Merced 565', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+56226323622',
#    'display_phone': '+56 2 2632 3622',
#    'distance': 1932.7058464670044},
#   {'id': '8dkDcJ_jAc4RPBqmmYKwXA',
#    'alias': 'dae-jang-kum-santiago',
#    'name': 'Dae Jang Kum',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/joQtcWzs-Cy1aMLl9D6Hvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dae-jang-kum-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 9,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4318428, 'longitude': -70.6399002},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Bombero Núñez 174',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8420000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Bombero Núñez 174', 'RM 8420000 Santiago', 'Chile']},
#    'phone': '+56227324772',
#    'display_phone': '+56 2 2732 4772',
#    'distance': 1883.818141496471},
#   {'id': 'Snago_jUk1ZNP2yQBpRpag',
#    'alias': 'seoul-santiago',
#    'name': 'Seoul',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OK-D0NHgoMcqDuB2TTLjyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seoul-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 3,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4291093, 'longitude': -70.6437498},
#    'transactions': [],
#    'location': {'address1': 'Sagrado Corazón 371',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Sagrado Corazón 371', 'RM Santiago', 'Chile']},
#    'phone': '+5627355689',
#    'display_phone': '+56 27355689',
#    'distance': 2351.505060860972},
#   {'id': 'ena69HR-tQZjtdMTC5czWw',
#    'alias': 'eccolo-qua-santiago-2',
#    'name': 'Eccolo Qua',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nhksjHFrsVzomSCWETydhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eccolo-qua-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4408082, 'longitude': -70.627771},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Condell 621',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7970000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Condell 621', 'RM 7970000 Santiago', 'Chile']},
#    'phone': '+56222222098',
#    'display_phone': '+56 2 2222 2098',
#    'distance': 395.76232318475917},
#   {'id': '7fUOuXtQBsskDnza60AXAw',
#    'alias': 'ootoya-santiago',
#    'name': 'Ootoya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/31KXjhS9Htkaf-ONEuwk1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ootoya-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 4,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.432904, 'longitude': -70.634749},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Constitución 125',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7520360',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Constitución 125', 'RM 7520360 Santiago', 'Chile']},
#    'phone': '+56981456978',
#    'display_phone': '+56 9 8145 6978',
#    'distance': 1485.8618510348438},
#   {'id': 'UV24IsNtNyM6_CQ84gJjOQ',
#    'alias': 'happening-santiago',
#    'name': 'Happening',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4uJQ3grQSWurdg2bOKKw6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happening-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 19,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'argentine', 'title': 'Argentine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4163155225805,
#     'longitude': -70.5954595103857},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Av. Apoquindo 3090',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7550000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Apoquindo 3090', 'RM 7550000 Santiago', 'Chile']},
#    'phone': '+56223621092',
#    'display_phone': '+56 2 2362 1092',
#    'distance': 4149.802259895764},
#   {'id': 'D7aZ9ZGpnyObEawvMsXi_A',
#    'alias': 'liguria-santiago-5',
#    'name': 'Liguria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mmbKvLTKbim8bq5nBnRtaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liguria-santiago-5?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 29,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.418295, 'longitude': -70.6028055},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Luis Thayer Ojeda 019',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Luis Thayer Ojeda 019',
#      'RM 7500000 Santiago',
#      'Chile']},
#    'phone': '+56222311393',
#    'display_phone': '+56 2 2231 1393',
#    'distance': 3545.4303326039294},
#   {'id': 'DcFioskEgID4sBcF_g5nvA',
#    'alias': 'fuente-italiana-santiago',
#    'name': 'Fuente Italiana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4u7FhGqtQF4RJyKZ5keKYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuente-italiana-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1,
#    'categories': [{'alias': 'cafeteria', 'title': 'Cafeteria'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.4492045, 'longitude': -70.6526558},
#    'transactions': [],
#    'location': {'address1': 'Paseo Bulnes 251',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Paseo Bulnes 251', 'RM Santiago', 'Chile']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2578.2819553788795},
#   {'id': 'e33bsBHIZAH8RMOh0Z4HRQ',
#    'alias': 'el-hoyo-santiago',
#    'name': 'El Hoyo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nvZl5h3k4LA87ceso1aGwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-hoyo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 9,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4553319270182,
#     'longitude': -70.6775925843539},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'San Vicente 375',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['San Vicente 375', 'RM Santiago', 'Chile']},
#    'phone': '+56226890339',
#    'display_phone': '+56 2 2689 0339',
#    'distance': 4988.158912117015},
#   {'id': 'tBgywF1cEV7iFJWCr0g8aA',
#    'alias': 'miyako-santiago-2',
#    'name': 'Miyako',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RjY2oYVaKrExtSSqhibhnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miyako-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 8,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4417647188203,
#     'longitude': -70.6485408472882},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Moneda 856',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Moneda 856', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+5624239911',
#    'display_phone': '+56 24239911',
#    'distance': 2140.5298198815235},
#   {'id': 'qRNEPSS9PqH98_oXsH3eRw',
#    'alias': 'el-mesón-nerudiano-santiago',
#    'name': 'El Mesón Nerudiano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nDQRU7ScPFp-Z-SfJSSKeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-mes%C3%B3n-nerudiano-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 11,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4301891746701,
#     'longitude': -70.636593073831},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Domínica 35',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Domínica 35', 'RM Santiago', 'Chile']},
#    'phone': '+5627371542',
#    'display_phone': '+56 27371542',
#    'distance': 1831.6863737411504},
#   {'id': 'MqpWMFlwLxYZq3q5WKhFgg',
#    'alias': 'rico-saigon-santiago',
#    'name': 'Rico Saigon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_4RR03ZtYYanQq8VhTDwmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rico-saigon-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 5,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.6422349, 'longitude': -70.7072703},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Santa Filomena 207',
#     'address2': None,
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Santa Filomena 207', 'RM Santiago', 'Chile']},
#    'phone': '+56989863369',
#    'display_phone': '+56 9 8986 3369',
#    'distance': 2163.0046158483815},
#   {'id': 'veOqBAWM7aepBqSVO9Z25g',
#    'alias': 'kinsa-providencia',
#    'name': 'Kinsa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3Ivbhr8qLkizyE0rBQ0KcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kinsa-providencia?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 4,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.43268, 'longitude': -70.63496},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Constitución 140',
#     'address2': '',
#     'address3': None,
#     'city': 'Providencia',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Constitución 140', 'RM Providencia', 'Chile']},
#    'phone': '+56229550000',
#    'display_phone': '+56 2 2955 0000',
#    'distance': 1528.3646841385298},
#   {'id': 'kb5XyraYJ1vuFAydgbcrwA',
#    'alias': 'tio-tomate-providencia',
#    'name': 'Tio Tomate',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mj4mbuc7Rin1gv3jxAjoEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tio-tomate-providencia?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.443678, 'longitude': -70.625992},
#    'transactions': [],
#    'location': {'address1': 'Av. Italia 975',
#     'address2': '',
#     'address3': None,
#     'city': 'Providencia',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Italia 975', 'RM Providencia', 'Chile']},
#    'phone': '+56223162176',
#    'display_phone': '+56 2 2316 2176',
#    'distance': 41.752775248128316},
#   {'id': 'SYjQB4CntxSQtkmI6Ep3Vw',
#    'alias': 'puerto-bellavista-santiago',
#    'name': 'Puerto Bellavista',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fRaF6dO-leTgj3mYvvTLbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/puerto-bellavista-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 12,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4341214738782,
#     'longitude': -70.6353939185184},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Patio Bellavista',
#     'address2': 'Pío Nono 77',
#     'address3': 'Local 71',
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Patio Bellavista',
#      'Pío Nono 77',
#      'Local 71',
#      'RM 7500000 Santiago',
#      'Chile']},
#    'phone': '+56226567015',
#    'display_phone': '+56 2 2656 7015',
#    'distance': 1414.5014967385566},
#   {'id': 'x4R6h8NqBQmEp-tAnyFO3g',
#    'alias': 'castillo-forestal-santiago',
#    'name': 'Castillo Forestal',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6h4WS1Cb0ZwI3fMxg84BMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/castillo-forestal-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 15,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4348361156787,
#     'longitude': -70.642646313429},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Cardenal José María Caro 390',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Cardenal José María Caro 390',
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+56226641544',
#    'display_phone': '+56 2 2664 1544',
#    'distance': 1873.3304901425852},
#   {'id': 'qtj5faNNgQEP9qhs48w5JA',
#    'alias': 'restaurant-módena-santiago-2',
#    'name': 'Restaurant Módena',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6ZGbGAUMO4CgPbt6buzAyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-m%C3%B3dena-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4277156, 'longitude': -70.6186098},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'General Flores 51',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['General Flores 51', 'RM Santiago', 'Chile']},
#    'phone': '+5627254711',
#    'display_phone': '+56 27254711',
#    'distance': 1910.8621405837464},
#   {'id': 'x72iXJX0J7kibMpisppZ9g',
#    'alias': 'liguria-manuel-montt-providencia',
#    'name': 'Liguria Manuel Montt',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6vwco8rSKMLqFyXSd3tu-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liguria-manuel-montt-providencia?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 26,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4284627395014,
#     'longitude': -70.6189616226266},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Providencia 1373',
#     'address2': None,
#     'address3': None,
#     'city': 'Providencia',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Providencia 1373',
#      'RM 7500000 Providencia',
#      'Chile']},
#    'phone': '+56222357914',
#    'display_phone': '+56 2 2235 7914',
#    'distance': 1821.6345304231281},
#   {'id': 'U15KdCy6HH05WISNtN9plQ',
#    'alias': 'restaurant-peumayén-santiago',
#    'name': 'Restaurant Peumayén',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1kkAJcgLnxqK6S-U6XVlQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-peumay%C3%A9n-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 60,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4328073, 'longitude': -70.6348213},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Constitución 136',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Constitución 136', 'RM 7500000 Santiago', 'Chile']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1498.5204503845584},
#   {'id': 'WOSMv9eCeFn2p3HhqJDzNg',
#    'alias': 'la-piojera-santiago',
#    'name': 'La Piojera',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k3wRKjie3qftMI0_iEco-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-piojera-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 17,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4335604326272,
#     'longitude': -70.6519935938484},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Aillavillú 1030',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Aillavillú 1030', 'RM Santiago', 'Chile']},
#    'phone': '+5626981682',
#    'display_phone': '+56 26981682',
#    'distance': 2703.52581305034},
#   {'id': 'bj89DyCaI801-LPZ6QFcug',
#    'alias': 'sarita-colonia-santiago-2',
#    'name': 'Sarita Colonia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6pr2c_s5KeqJk_SisK9B6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sarita-colonia-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 14,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4330661, 'longitude': -70.6425858},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Loreto 40',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Loreto 40', 'RM Santiago', 'Chile']},
#    'phone': '+56228813937',
#    'display_phone': '+56 2 2881 3937',
#    'distance': 1981.451753264516},
#   {'id': 'jRi_FMiE3dbNZ9iL-jw4Og',
#    'alias': 'hansoban-santiago',
#    'name': 'Hansoban',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VCaF6DBiqrUZs1ABF5SfAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hansoban-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 14,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4310893, 'longitude': -70.6433972},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Rio de Janeiro 248',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8420413',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Rio de Janeiro 248', 'RM 8420413 Santiago', 'Chile']},
#    'phone': '+568420413',
#    'display_phone': '+56 8420413',
#    'distance': 2178.497886272044}],
#  'total': 2200,
#  'region': {'center': {'longitude': -70.6256103515625,
#    'latitude': -33.44387694471913}}}

# %%
restaurantes.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
restaurantes['total']
# Out:
# 2200

# %%
restaurantes['region']
# Out:
# {'center': {'longitude': -70.6256103515625, 'latitude': -33.44387694471913}}

# %%
restaurantes['businesses'][0]
# Out:
# {'id': '8N6Y3HsLXHBeFwhlO0YxwQ',
#  'alias': 'barrica-94-santiago',
#  'name': 'Barrica 94',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nuJaODltnNB6J_ww3g-JyA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/barrica-94-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#  'review_count': 72,
#  'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#   {'alias': 'chilean', 'title': 'Chilean'},
#   {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': -33.4342880070125,
#   'longitude': -70.6352240592241},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': 'Bellavista 052',
#   'address2': '',
#   'address3': '',
#   'city': 'Santiago',
#   'zip_code': '8320000',
#   'country': 'CL',
#   'state': 'RM',
#   'display_address': ['Bellavista 052', 'RM 8320000 Santiago', 'Chile']},
#  'phone': '+5627324939',
#  'display_phone': '+56 27324939',
#  'distance': 1390.184857350938}

# %%
df = pd.DataFrame(restaurantes['businesses'])
df.head()
# Out:
#                        id                      alias            name  \
# 0  8N6Y3HsLXHBeFwhlO0YxwQ        barrica-94-santiago      Barrica 94
# 1  KQ2D3gs9y0wIuTqoKOHO4w           mestizo-santiago         Mestizo
# 2  y2FR-JBGie4wiW6RjtKLhg    aquí-está-coco-santiago  Aquí Está Coco
# 3  FTnehJpfn5t3iq_eGcE6pg           galindo-santiago         Galindo
# 4  CAFL80wAGOMcPrEO6uMnkA  fuente-alemana-santiago-2  Fuente Alemana
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/nuJaOD...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/XBkpGr...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/6IkPzb...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/GHOdcj...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/BqZVmt...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/barrica-94-santiago?a...            72
# 1  https://www.yelp.com/biz/mestizo-santiago?adju...            52
# 2  https://www.yelp.com/biz/aqu%C3%AD-est%C3%A1-c...            52
# 3  https://www.yelp.com/biz/galindo-santiago?adju...            57
# 4  https://www.yelp.com/biz/fuente-alemana-santia...            55
#
#                                           categories  rating  \
# 0  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.5
# 1  [{'alias': 'chilean', 'title': 'Chilean'}, {'a...     4.5
# 2         [{'alias': 'seafood', 'title': 'Seafood'}]     4.5
# 3  [{'alias': 'chilean', 'title': 'Chilean'}, {'a...     4.0
# 4   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     4.5
#
#                                          coordinates transactions price  \
# 0  {'latitude': -33.4342880070125, 'longitude': -...           []    $$
# 1  {'latitude': -33.394083457956, 'longitude': -7...           []  $$$$
# 2  {'latitude': -33.42406349, 'longitude': -70.61...           []  $$$$
# 3  {'latitude': -33.433069, 'longitude': -70.634928}           []    $$
# 4  {'latitude': -33.4375198417072, 'longitude': -...           []    $$
#
#                                             location         phone  \
# 0  {'address1': 'Bellavista 052', 'address2': '',...   +5627324939
# 1  {'address1': 'Av. del Bicentenario 4050', 'add...  +56974776093
# 2  {'address1': 'La Concepción 236', 'address2': ...   +5624106200
# 3  {'address1': 'Dardignac 98', 'address2': None,...  +56227770116
# 4  {'address1': 'Av. Libertador Bernardo O'Higgin...   +5626393231
#
#      display_phone     distance
# 0     +56 27324939  1390.184857
# 1  +56 9 7477 6093  6024.195625
# 2     +56 24106200  2355.685975
# 3  +56 2 2777 0116  1480.470569
# 4     +56 26393231  1197.179790

# %% [markdown]
# ## 5. Conciertos de la Filarmónica de NY
#
# Revisemos ahora un archivo JSON más grande, con los datos de los conciertos de la Orquesta Filarmónica de Nueva York.
#
# El `json` de la filarmónica tiene el siguiente formato:
#
# ```
# {
#   "programs": [
#     {
#       "id": "38e072a7-8fc9-4f9a-8eac-3957905c0002", // GUID
#       "programID": "3853", // NYP Local ID
#       "orchestra": "New York Philharmonic",
#       "season": "1842-43",
#       "concerts": [
#         {
#            "eventType": "Subscription Season",
#            "Location": "Manhattan, NY",
#            "Venue": "Apollo Rooms",
#            "Date": "1842-12-07T05:00:00Z",
#            "Time": "8:00PM"
#         },
#         /* A program can have multiple concerts */
#       ],
#       "works": [
#         {
#           "ID": "8834*4", // e.g. "1234*1" - first part is the Work ID, second part is the NYP Movement ID
#           "composerName": "Weber,  Carl  Maria Von",
#           "workTitle": "OBERON",
#           "movement": "\"Ozean, du Ungeheuer\" (Ocean, thou mighty monster), Reiza (Scene and Aria), Act II",
#           "conductorName": "Timm, Henry C.",
#           "soloists": [
#             {
#               "soloistName": "Otto, Antoinette",
#               "soloistInstrument": "Soprano",
#               "soloistRoles": "S"
#             },
#             /* more soloists, if applicable. If no soloists, this will be an empty array */
#           ]
#         },
#         /* a program will usually have multiple works */
#         {
#           "ID": "0*",
#           "interval": "Intermission",
#           "soloists": []
#         },
#         /* Intermissions will also appear in the works array */
#       ]
#     },
#     /* more programs */
#   ]
# }
# ```

# %%
datos_raw = json.load(open('complete.json','r', encoding='UTF-8'))
type(datos_raw)
# Out:
# dict

# %%
datos_raw['programs'][0].keys()
# Out:
# dict_keys(['id', 'programID', 'orchestra', 'season', 'concerts', 'works'])

# %%
datos_raw['programs'][0]
# Out:
# {'id': '00646b9f-fec7-4ffb-9fb1-faae410bd9dc-0.1',
#  'programID': '3853',
#  'orchestra': 'New York Philharmonic',
#  'season': '1842-43',
#  'concerts': [{'eventType': 'Subscription Season',
#    'Location': 'Manhattan, NY',
#    'Venue': 'Apollo Rooms',
#    'Date': '1842-12-07T05:00:00Z',
#    'Time': '8:00PM'}],
#  'works': [{'ID': '52446*',
#    'composerName': 'Beethoven,  Ludwig  van',
#    'workTitle': 'SYMPHONY NO. 5 IN C MINOR, OP.67',
#    'conductorName': 'Hill, Ureli Corelli',
#    'soloists': []},
#   {'ID': '8834*4',
#    'composerName': 'Weber,  Carl  Maria Von',
#    'workTitle': 'OBERON',
#    'movement': '"Ozean, du Ungeheuer" (Ocean, thou mighty monster), Reiza (Scene and Aria), Act II',
#    'conductorName': 'Timm, Henry C.',
#    'soloists': [{'soloistName': 'Otto, Antoinette',
#      'soloistInstrument': 'Soprano',
#      'soloistRoles': 'S'}]},
#   {'ID': '3642*',
#    'composerName': 'Hummel,  Johann',
#    'workTitle': 'QUINTET, PIANO, D MINOR, OP. 74',
#    'soloists': [{'soloistName': 'Scharfenberg, William',
#      'soloistInstrument': 'Piano',
#      'soloistRoles': 'A'},
#     {'soloistName': 'Hill, Ureli Corelli',
#      'soloistInstrument': 'Violin',
#      'soloistRoles': 'A'},
#     {'soloistName': 'Derwort, G. H.',
#      'soloistInstrument': 'Viola',
#      'soloistRoles': 'A'},
#     {'soloistName': 'Boucher, Alfred',
#      'soloistInstrument': 'Cello',
#      'soloistRoles': 'A'},
#     {'soloistName': 'Rosier, F. W.',
#      'soloistInstrument': 'Double Bass',
#      'soloistRoles': 'A'}]},
#   {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#   {'ID': '8834*3',
#    'composerName': 'Weber,  Carl  Maria Von',
#    'workTitle': 'OBERON',
#    'movement': 'Overture',
#    'conductorName': 'Etienne, Denis G.',
#    'soloists': []},
#   {'ID': '8835*1',
#    'composerName': 'Rossini,  Gioachino',
#    'workTitle': 'ARMIDA',
#    'movement': 'Duet',
#    'conductorName': 'Timm, Henry C.',
#    'soloists': [{'soloistName': 'Otto, Antoinette',
#      'soloistInstrument': 'Soprano',
#      'soloistRoles': 'S'},
#     {'soloistName': 'Horn, Charles Edward',
#      'soloistInstrument': 'Tenor',
#      'soloistRoles': 'S'}]},
#   {'ID': '8837*6',
#    'composerName': 'Beethoven,  Ludwig  van',
#    'workTitle': 'FIDELIO, OP. 72',
#    'movement': '"In Des Lebens Fruhlingstagen...O spur ich nicht linde," Florestan (aria)',
#    'conductorName': 'Timm, Henry C.',
#    'soloists': [{'soloistName': 'Horn, Charles Edward',
#      'soloistInstrument': 'Tenor',
#      'soloistRoles': 'S'}]},
#   {'ID': '8336*4',
#    'composerName': 'Mozart,  Wolfgang  Amadeus',
#    'workTitle': 'ABDUCTION FROM THE SERAGLIO,THE, K.384',
#    'movement': '"Ach Ich liebte," Konstanze (aria)',
#    'conductorName': 'Timm, Henry C.',
#    'soloists': [{'soloistName': 'Otto, Antoinette',
#      'soloistInstrument': 'Soprano',
#      'soloistRoles': 'S'}]},
#   {'ID': '5543*',
#    'composerName': 'Kalliwoda,  Johann  W.',
#    'workTitle': 'OVERTURE NO. 1, D MINOR, OP. 38',
#    'conductorName': 'Timm, Henry C.',
#    'soloists': []}]}

# %%
datos_raw['programs'][0]['concerts']
# Out:
# [{'eventType': 'Subscription Season',
#   'Location': 'Manhattan, NY',
#   'Venue': 'Apollo Rooms',
#   'Date': '1842-12-07T05:00:00Z',
#   'Time': '8:00PM'}]

# %%
datos_raw['programs'][0]['works']
# Out:
# [{'ID': '52446*',
#   'composerName': 'Beethoven,  Ludwig  van',
#   'workTitle': 'SYMPHONY NO. 5 IN C MINOR, OP.67',
#   'conductorName': 'Hill, Ureli Corelli',
#   'soloists': []},
#  {'ID': '8834*4',
#   'composerName': 'Weber,  Carl  Maria Von',
#   'workTitle': 'OBERON',
#   'movement': '"Ozean, du Ungeheuer" (Ocean, thou mighty monster), Reiza (Scene and Aria), Act II',
#   'conductorName': 'Timm, Henry C.',
#   'soloists': [{'soloistName': 'Otto, Antoinette',
#     'soloistInstrument': 'Soprano',
#     'soloistRoles': 'S'}]},
#  {'ID': '3642*',
#   'composerName': 'Hummel,  Johann',
#   'workTitle': 'QUINTET, PIANO, D MINOR, OP. 74',
#   'soloists': [{'soloistName': 'Scharfenberg, William',
#     'soloistInstrument': 'Piano',
#     'soloistRoles': 'A'},
#    {'soloistName': 'Hill, Ureli Corelli',
#     'soloistInstrument': 'Violin',
#     'soloistRoles': 'A'},
#    {'soloistName': 'Derwort, G. H.',
#     'soloistInstrument': 'Viola',
#     'soloistRoles': 'A'},
#    {'soloistName': 'Boucher, Alfred',
#     'soloistInstrument': 'Cello',
#     'soloistRoles': 'A'},
#    {'soloistName': 'Rosier, F. W.',
#     'soloistInstrument': 'Double Bass',
#     'soloistRoles': 'A'}]},
#  {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#  {'ID': '8834*3',
#   'composerName': 'Weber,  Carl  Maria Von',
#   'workTitle': 'OBERON',
#   'movement': 'Overture',
#   'conductorName': 'Etienne, Denis G.',
#   'soloists': []},
#  {'ID': '8835*1',
#   'composerName': 'Rossini,  Gioachino',
#   'workTitle': 'ARMIDA',
#   'movement': 'Duet',
#   'conductorName': 'Timm, Henry C.',
#   'soloists': [{'soloistName': 'Otto, Antoinette',
#     'soloistInstrument': 'Soprano',
#     'soloistRoles': 'S'},
#    {'soloistName': 'Horn, Charles Edward',
#     'soloistInstrument': 'Tenor',
#     'soloistRoles': 'S'}]},
#  {'ID': '8837*6',
#   'composerName': 'Beethoven,  Ludwig  van',
#   'workTitle': 'FIDELIO, OP. 72',
#   'movement': '"In Des Lebens Fruhlingstagen...O spur ich nicht linde," Florestan (aria)',
#   'conductorName': 'Timm, Henry C.',
#   'soloists': [{'soloistName': 'Horn, Charles Edward',
#     'soloistInstrument': 'Tenor',
#     'soloistRoles': 'S'}]},
#  {'ID': '8336*4',
#   'composerName': 'Mozart,  Wolfgang  Amadeus',
#   'workTitle': 'ABDUCTION FROM THE SERAGLIO,THE, K.384',
#   'movement': '"Ach Ich liebte," Konstanze (aria)',
#   'conductorName': 'Timm, Henry C.',
#   'soloists': [{'soloistName': 'Otto, Antoinette',
#     'soloistInstrument': 'Soprano',
#     'soloistRoles': 'S'}]},
#  {'ID': '5543*',
#   'composerName': 'Kalliwoda,  Johann  W.',
#   'workTitle': 'OVERTURE NO. 1, D MINOR, OP. 38',
#   'conductorName': 'Timm, Henry C.',
#   'soloists': []}]

# %%
# tratemos de crear un DataFrame
nycphil = pd.json_normalize(datos_raw['programs'])
nycphil.head()
# Out:
#                                          id programID  \
# 0  00646b9f-fec7-4ffb-9fb1-faae410bd9dc-0.1      3853
# 1  1118e84e-eb59-46cc-9119-d903375e65e6-0.1      5178
# 2  08536612-27c3-437e-9b44-def21034b06c-0.1     10785
# 3  81a3b8de-1737-4c9e-9318-b839f7c7c4c0-0.1      5887
# 4  09581bb7-8855-4965-b302-fc54cc669041-0.1       305
#
#                                   orchestra   season  \
# 0                     New York Philharmonic  1842-43
# 1                     New York Philharmonic  1842-43
# 2  Musicians from the New York Philharmonic  1842-43
# 3                     New York Philharmonic  1842-43
# 4                     New York Philharmonic  1843-44
#
#                                             concerts  \
# 0  [{'eventType': 'Subscription Season', 'Locatio...
# 1  [{'eventType': 'Subscription Season', 'Locatio...
# 2  [{'eventType': 'Special', 'Location': 'Manhatt...
# 3  [{'eventType': 'Subscription Season', 'Locatio...
# 4  [{'eventType': 'Subscription Season', 'Locatio...
#
#                                                works
# 0  [{'ID': '52446*', 'composerName': 'Beethoven, ...
# 1  [{'ID': '52437*', 'composerName': 'Beethoven, ...
# 2  [{'ID': '52364*1', 'composerName': 'Beethoven,...
# 3  [{'ID': '52434*', 'composerName': 'Beethoven, ...
# 4  [{'ID': '52453*', 'composerName': 'Beethoven, ...

# %% [markdown]
# Vemos dos columnas que tienen datos anidados. Usemos la función `json_normalize` para desempacar la columna de conciertos en un nuevo DataFrame

# %%
concert_data = pd.json_normalize(data=datos_raw['programs'], record_path='concerts', meta=['id', 'orchestra','programID', 'season'])
concert_data.head()
# Out:
#              eventType       Location         Venue                  Date  \
# 0  Subscription Season  Manhattan, NY  Apollo Rooms  1842-12-07T05:00:00Z
# 1  Subscription Season  Manhattan, NY  Apollo Rooms  1843-02-18T05:00:00Z
# 2              Special  Manhattan, NY  Apollo Rooms  1843-04-07T05:00:00Z
# 3  Subscription Season  Manhattan, NY  Apollo Rooms  1843-04-22T05:00:00Z
# 4  Subscription Season  Manhattan, NY  Apollo Rooms  1843-11-18T05:00:00Z
#
#      Time                                        id  \
# 0  8:00PM  00646b9f-fec7-4ffb-9fb1-faae410bd9dc-0.1
# 1  8:00PM  1118e84e-eb59-46cc-9119-d903375e65e6-0.1
# 2  8:00PM  08536612-27c3-437e-9b44-def21034b06c-0.1
# 3  8:00PM  81a3b8de-1737-4c9e-9318-b839f7c7c4c0-0.1
# 4    None  09581bb7-8855-4965-b302-fc54cc669041-0.1
#
#                                   orchestra programID   season
# 0                     New York Philharmonic      3853  1842-43
# 1                     New York Philharmonic      5178  1842-43
# 2  Musicians from the New York Philharmonic     10785  1842-43
# 3                     New York Philharmonic      5887  1842-43
# 4                     New York Philharmonic       305  1843-44

# %% [markdown]
# ¿Cuántos conciertos han realizado desde el 7 de diciembre de 1842?

# %%
len(concert_data)
# Out:
# 22820

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Desafío:</b> Convierta el archivo `json` en un DataFrame aplanado centrado en `works` y conteste: ¿cuál es el compositor del que más piezas ha tocado la Filarmónica de NY en estos 181 años de datos?
#
# <b> Las tres primeras respuestas correctas tienen +0.1 en la Tarea 1.</b>
# </div>
